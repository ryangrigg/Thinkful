# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf #needed for models in this script
import pylab as pl
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
pd.set_option('html', True) #see the dataframe in a more user friendly manner
# %matplotlib inline

# %% [markdown]
# ## Profiling Data

# %% [markdown]
# As you saw in the last unit, we can profile data both by computing important statistics and by visually inspecting the data. Visual inspection is important in order to understand the overall structure and composition of the data. Sometimes outliers are noise and sometimes they are vital points to be analyzed and understood. Whatever the case, visual inspection is also important for understanding the limitations of our analytical tools.
#
# For example, there is the famous case of Anscombe's Quartet. This was an exercise whereby four very different datasets were composed with the same statistical measures (mean, variance, correlation, and linear regression line):
#
# ![](files/nycbike1.jpg)
#
# The descriptive statistics you learned before are important, but they're not the end of the story. Be sure to visualize your data and understand the limits of your analysis. For example, if you have a long-tail distribution, like the credit distribution from previous lessons:
#
# ![](files/nycbike2.jpg)
#
# The mean becomes much less helpful for understanding the data distribution, and you'll want to use the median. Household income and age are both good examples of attributes that usually have a long tail and are best described by the median rather than the mean.

# %% [markdown]
# ## Download Citi Bike Station Data

# %% [markdown]
# One of the important things data scientists bring to their work is not only advanced tools, but a curiosity about the context for their data. We call this "domain knowledge". In this case, the domain would be bike share programs, specificaly the bike share program in New York City. Domain knowledge is essential to producing accurate and useful analysis. Without such knowledge, it's easy to produce models that describe something that is neither useful or important. In some cases, you may already be familiar with the domain, but often we're asked to work in a domain in which we have no expertise. In those cases, it's important that you be able to quickly acquire the necessary domain expertise to properly apply the skills you've gained in order to both ask the right questions and produce meaningful and accurate results. For a discussion of this from some of the leaders in the field of data science, see this recent debate on the topic (http://medriscoll.com/post/18784448854/the-data-science-debate-domain-expertise-or).

# %% [markdown]
# <b>Goal:</b> Record the number of bikes available every minute for an hour across all of New York City in order to see which station or set of stations is the most active in New York City for that hour. Activity is defined as the total number of bicycles taken out or returned in an hour. So if 2 bikes are brought in and 4 bikes are taken out, that station has an activity level of 6.
# <b>Note:</b> It's important to define the terms of analysis. In this case, activity has a particular definition. In many cases, the measurement of interest could be defined in many ways and it's important to be as specific as possible. For example, in studying outcomes from an experimental drug treatment, "success" may be defined as prolonging life for a certain amount of time, 6 months, over some estimated baseline. Ideas like "better", "best", "successful", and "enjoyable" need to be defined such that they can be measured and compared, even if in doing so much of the common meaning for the terms is lost.

# %% [markdown]
# ### Import package to access URL

# %% [markdown]
# To download from a URL, we need to use a special package that handles going to the Internet and downloading the resulting page. In this case, we'll be using a package called requests (package that allows us to download data from any online resource). Documentation for this package: http://docs.python-requests.org/en/latest/

# %%
import requests

# %% [markdown]
# ### Access the URL

# %%
nyc_bike = requests.get('http://www.citibikenyc.com/stations/json')

# %% [markdown]
# <b>Note:</b> Usually (and the supporting documents) use 'r.' for requests (Ex. r = requests.get('http://www.citibikenyc.com/stations/json'). However, as above, you can call the file you are requesting anything you wish (nyc_bike above) and then you access the commands associated with requests by typing the name of the file you created followed by a period and then tab; for nyc_bike it would look like: nyc_bike. [tab]
#
# Although not in iPython, the commands available are the same as:
#
# ![](files/nycbike3.jpg)

# %% [markdown]
# You can see there are a number of available methods. The ones you want right now are the ones that allow us to view the actual content of the request. You can see the webpage you downloaded for yourself (http://www.citibikenyc.com/stations/json).

# %% [markdown]
# <b>Note:</b> In Chrome, you can install the JSONView extension that will automatically format JSON files to be more readible in the browser. Download it here: https://chrome.google.com/webstore/detail/jsonview/chklaanhfefbnpoihckbnefhakgolnmc?utm_source=chrome-ntp-icon

# %% [markdown]
# To get a basic view of the text type:

# %%
nyc_bike.text
# Out:
# u'{"executionTime":"2015-11-03 10:36:09 AM","stationBeanList":[{"id":72,"stationName":"W 52 St & 11 Ave","availableDocks":37,"totalDocks":39,"latitude":40.76727216,"longitude":-73.99392888,"statusValue":"In Service","statusKey":1,"availableBikes":1,"stAddress1":"W 52 St & 11 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:35:45 AM","landMark":""},{"id":79,"stationName":"Franklin St & W Broadway","availableDocks":11,"totalDocks":33,"latitude":40.71911552,"longitude":-74.00666661,"statusValue":"In Service","statusKey":1,"availableBikes":22,"stAddress1":"Franklin St & W Broadway","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:35:39 AM","landMark":""},{"id":82,"stationName":"St James Pl & Pearl St","availableDocks":10,"totalDocks":27,"latitude":40.71117416,"longitude":-74.00016545,"statusValue":"In Service","statusKey":1,"availableBikes":17,"stAddress1":"St James Pl & Pearl St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:33:17 AM","landMark":""},{"id":83,"stationName":"Atlantic Ave & Fort Greene Pl","availableDocks":47,"totalDocks":62,"latitude":40.68382604,"longitude":-73.97632328,"statusValue":"In Service","statusKey":1,"availableBikes":15,"stAddress1":"Atlantic Ave & Fort Greene Pl","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:33:16 AM","landMark":""},{"id":116,"stationName":"W 17 St & 8 Ave","availableDocks":31,"totalDocks":39,"latitude":40.74177603,"longitude":-74.00149746,"statusValue":"In Service","statusKey":1,"availableBikes":8,"stAddress1":"W 17 St & 8 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:32:21 AM","landMark":""},{"id":119,"stationName":"Park Ave & St Edwards St","availableDocks":16,"totalDocks":19,"latitude":40.69608941,"longitude":-73.97803415,"statusValue":"In Service","statusKey":1,"availableBikes":3,"stAddress1":"Park Ave & St Edwards St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:35:58 AM","landMark":""},{"id":120,"stationName":"Lexington Ave & Classon Ave","availableDocks":16,"totalDocks":19,"latitude":40.68676793,"longitude":-73.95928168,"statusValue":"In Service","statusKey":1,"availableBikes":3,"stAddress1":"Lexington Ave & Classon Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:33:22 AM","landMark":""},{"id":127,"stationName":"Barrow St & Hudson St","availableDocks":0,"totalDocks":31,"latitude":40.73172428,"longitude":-74.00674436,"statusValue":"In Service","statusKey":1,"availableBikes":30,"stAddress1":"Barrow St & Hudson St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:35:07 AM","landMark":""},{"id":128,"stationName":"MacDougal St & Prince St","availableDocks":28,"totalDocks":29,"latitude":40.72710258,"longitude":-74.00297088,"statusValue":"Not In Service","statusKey":3,"availableBikes":0,"stAddress1":"MacDougal St & Prince St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-09-24 09:23:40 AM","landMark":""},{"id":137,"stationName":"E 56 St & Madison Ave","availableDocks":0,"totalDocks":46,"latitude":40.761628,"longitude":-73.972924,"statusValue":"In Service","statusKey":1,"availableBikes":46,"stAddress1":"E 56 St & Madison Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2015-11-03 10:34:38 AM","landMark":""},{"id":143,"stationName":"Clinton St & Joralemon St","availableDocks":17,"totalDock ...

# %% [markdown]
# You can see this all comes out as a blob of text. Technically speaking, it's all one long string of text, which would be difficult to parse if you didn't have another function that will make the text easier to read, json().
#
# Type this and see what you get:

# %%
nyc_bike.json()
# Out:
# {u'executionTime': u'2015-11-03 10:36:09 AM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 37,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:45 AM',
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:39 AM',
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Franklin St & W Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 82,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:17 AM',
#    u'latitude': 40.71117416,
#    u'location': u'',
#    u'longitude': -74.00016545,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 47,
#    u'city': u'',
#    u'id': 83,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:16 AM',
#    u'latitude': 40.68382604,
#    u'location': u'',
#    u'longitude': -73.97632328,
#    u'postalCode': u'',
#    u'stAddress1': u'Atlantic Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Atlantic Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 62},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 116,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:21 AM',
#    u'latitude': 40.74177603,
#    u'location': u'',
#    u'longitude': -74.00149746,
#    u'postalCode': u'',
#    u'stAddress1': u'W 17 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 17 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 119,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:58 AM',
#    u'latitude': 40.69608941,
#    u'location': u'',
#    u'longitude': -73.97803415,
#    u'postalCode': u'',
#    u'stAddress1': u'Park Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Park Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 120,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:22 AM',
#    u'latitude': 40.68676793,
#    u'location': u'',
#    u'longitude': -73.95928168,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 30,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 127,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:07 AM',
#    u'latitude': 40.73172428,
#    u'location': u'',
#    u'longitude': -74.00674436,
#    u'postalCode': u'',
#    u'stAddress1': u'Barrow St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Barrow St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 128,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-24 09:23:40 AM',
#    u'latitude': 40.72710258,
#    u'location': u'',
#    u'longitude': -74.00297088,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Prince St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 46,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 137,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:38 AM',
#    u'latitude': 40.761628,
#    u'location': u'',
#    u'longitude': -73.972924,
#    u'postalCode': u'',
#    u'stAddress1': u'E 56 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 56 St & Madison Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 46},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 143,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:07 AM',
#    u'latitude': 40.69239502,
#    u'location': u'',
#    u'longitude': -73.99337909,
#    u'postalCode': u'',
#    u'stAddress1': u'Clinton St & Joralemon St',
#    u'stAddress2': u'',
#    u'stationName': u'Clinton St & Joralemon St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 144,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:21 AM',
#    u'latitude': 40.69839895,
#    u'location': u'',
#    u'longitude': -73.98068914,
#    u'postalCode': u'',
#    u'stAddress1': u'Nassau St & Navy St',
#    u'stAddress2': u'',
#    u'stationName': u'Nassau St & Navy St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 38,
#    u'city': u'',
#    u'id': 146,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:01:57 AM',
#    u'latitude': 40.71625008,
#    u'location': u'',
#    u'longitude': -74.0091059,
#    u'postalCode': u'',
#    u'stAddress1': u'Hudson St & Reade St',
#    u'stAddress2': u'',
#    u'stationName': u'Hudson St & Reade St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 147,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:34 AM',
#    u'latitude': 40.71542197,
#    u'location': u'',
#    u'longitude': -74.01121978,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Warren St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 150,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:45 AM',
#    u'latitude': 40.7208736,
#    u'location': u'',
#    u'longitude': -73.98085795,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue C',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue C',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 151,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:01 AM',
#    u'latitude': 40.722103786686,
#    u'location': u'',
#    u'longitude': -73.997249007225,
#    u'postalCode': u'',
#    u'stAddress1': u'Cleveland Pl & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Cleveland Pl & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 152,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:40 AM',
#    u'latitude': 40.71473993,
#    u'location': u'',
#    u'longitude': -74.00910627,
#    u'postalCode': u'',
#    u'stAddress1': u'Warren St & Church St',
#    u'stAddress2': u'',
#    u'stationName': u'Warren St & Church St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 153,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'1969-12-31 07:00:00 PM',
#    u'latitude': 40.752062307,
#    u'location': u'',
#    u'longitude': -73.9816324043,
#    u'postalCode': u'',
#    u'stAddress1': u'E 40 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 40 St & 5 Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 3},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 157,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:45 AM',
#    u'latitude': 40.69089272,
#    u'location': u'',
#    u'longitude': -73.99612349,
#    u'postalCode': u'',
#    u'stAddress1': u'Henry St & Atlantic Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Henry St & Atlantic Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 160,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:07 AM',
#    u'latitude': 40.748238,
#    u'location': u'',
#    u'longitude': -73.978311,
#    u'postalCode': u'',
#    u'stAddress1': u'E 37 St & Lexington Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 37 St & Lexington Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 161,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:47 AM',
#    u'latitude': 40.72917025,
#    u'location': u'',
#    u'longitude': -73.99810231,
#    u'postalCode': u'',
#    u'stAddress1': u'LaGuardia Pl & W 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'LaGuardia Pl & W 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 45,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 164,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:17 AM',
#    u'latitude': 40.75323098,
#    u'location': u'',
#    u'longitude': -73.97032517,
#    u'postalCode': u'',
#    u'stAddress1': u'E 47 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 47 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 40,
#    u'city': u'',
#    u'id': 167,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:26 AM',
#    u'latitude': 40.7489006,
#    u'location': u'',
#    u'longitude': -73.97604882,
#    u'postalCode': u'',
#    u'stAddress1': u'E 39 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 39 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 44,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 168,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:19 AM',
#    u'latitude': 40.73971301,
#    u'location': u'',
#    u'longitude': -73.99456405,
#    u'postalCode': u'',
#    u'stAddress1': u'W 18 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 18 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 45,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 173,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:28 AM',
#    u'latitude': 40.76064679,
#    u'location': u'',
#    u'longitude': -73.98442659,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 49 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 49 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 51},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 174,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:12 AM',
#    u'latitude': 40.7381765,
#    u'location': u'',
#    u'longitude': -73.97738662,
#    u'postalCode': u'',
#    u'stAddress1': u'E 25 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 25 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 45,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 195,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:26 AM',
#    u'latitude': 40.70905623,
#    u'location': u'',
#    u'longitude': -74.01043382,
#    u'postalCode': u'',
#    u'stAddress1': u'Liberty St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Liberty St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 212,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:36 AM',
#    u'latitude': 40.74334935,
#    u'location': u'',
#    u'longitude': -74.00681753,
#    u'postalCode': u'',
#    u'stAddress1': u'W 16 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 16 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 28},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 216,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:14 AM',
#    u'latitude': 40.70037867,
#    u'location': u'',
#    u'longitude': -73.99548059,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Heights & Cranberry St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Heights & Cranberry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 217,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:09 AM',
#    u'latitude': 40.70277159,
#    u'location': u'',
#    u'longitude': -73.99383605,
#    u'postalCode': u'',
#    u'stAddress1': u'Old Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Old Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 218,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:46 AM',
#    u'latitude': 40.69028437,
#    u'location': u'',
#    u'longitude': -73.98707105,
#    u'postalCode': u'',
#    u'stAddress1': u'Gallatin Pl & Livingston St',
#    u'stAddress2': u'',
#    u'stationName': u'Gallatin Pl & Livingston St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 223,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:04 AM',
#    u'latitude': 40.73781509,
#    u'location': u'',
#    u'longitude': -73.99994661,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 7 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 7 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 224,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:02 AM',
#    u'latitude': 40.71146364,
#    u'location': u'',
#    u'longitude': -74.00552427,
#    u'postalCode': u'',
#    u'stAddress1': u'Spruce St & Nassau St',
#    u'stAddress2': u'',
#    u'stationName': u'Spruce St & Nassau St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 31,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 225,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:50 AM',
#    u'latitude': 40.74195138,
#    u'location': u'',
#    u'longitude': -74.00803013,
#    u'postalCode': u'',
#    u'stAddress1': u'W 14 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 14 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 54,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 228,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:52 AM',
#    u'latitude': 40.7546011026,
#    u'location': u'',
#    u'longitude': -73.971878855,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 229,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:25 AM',
#    u'latitude': 40.72743423,
#    u'location': u'',
#    u'longitude': -73.99379025,
#    u'postalCode': u'',
#    u'stAddress1': u'Great Jones St',
#    u'stAddress2': u'',
#    u'stationName': u'Great Jones St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 232,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:17 AM',
#    u'latitude': 40.69597683,
#    u'location': u'',
#    u'longitude': -73.99014892,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza E & Tillary St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza E & Tillary St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 233,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:38 AM',
#    u'latitude': 40.694757013639,
#    u'location': u'',
#    u'longitude': -73.990527391434,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza W & Pierrepont St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza W & Pierrepont St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 38},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 38,
#    u'city': u'',
#    u'id': 236,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:20 AM',
#    u'latitude': 40.7284186,
#    u'location': u'',
#    u'longitude': -73.98713956,
#    u'postalCode': u'',
#    u'stAddress1': u'St Marks Pl & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'St Marks Pl & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 237,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:50 AM',
#    u'latitude': 40.73047309,
#    u'location': u'',
#    u'longitude': -73.98672378,
#    u'postalCode': u'',
#    u'stAddress1': u'E 11 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 11 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 238,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:53 AM',
#    u'latitude': 40.7361967,
#    u'location': u'',
#    u'longitude': -74.00859207,
#    u'postalCode': u'',
#    u'stAddress1': u'Bank St & Washington St',
#    u'stAddress2': u'',
#    u'stationName': u'Bank St & Washington St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 239,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:10 AM',
#    u'latitude': 40.69196566,
#    u'location': u'',
#    u'longitude': -73.9813018,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby St & Fleet St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby St & Fleet St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 241,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:13 AM',
#    u'latitude': 40.68981035,
#    u'location': u'',
#    u'longitude': -73.97493121,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & S Portland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & S Portland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 242,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:55 AM',
#    u'latitude': 40.697787,
#    u'location': u'',
#    u'longitude': -73.973736,
#    u'postalCode': u'',
#    u'stAddress1': u'Carlton Ave & Flushing Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Carlton Ave & Flushing Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 243,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:33 AM',
#    u'latitude': 40.688226,
#    u'location': u'',
#    u'longitude': -73.979382,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Rockwell Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Rockwell Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 244,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:24 AM',
#    u'latitude': 40.69196035,
#    u'location': u'',
#    u'longitude': -73.96536851,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby Ave & Hall St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby Ave & Hall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 245,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:57 AM',
#    u'latitude': 40.69327018,
#    u'location': u'',
#    u'longitude': -73.97703874,
#    u'postalCode': u'',
#    u'stAddress1': u'Myrtle Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Myrtle Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 247,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:06 AM',
#    u'latitude': 40.73535398,
#    u'location': u'',
#    u'longitude': -74.00483091,
#    u'postalCode': u'',
#    u'stAddress1': u'Perry St & Bleecker St',
#    u'stAddress2': u'',
#    u'stationName': u'Perry St & Bleecker St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 248,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:26 AM',
#    u'latitude': 40.72185379,
#    u'location': u'',
#    u'longitude': -74.00771779,
#    u'postalCode': u'',
#    u'stAddress1': u'Laight St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Laight St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 25,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 249,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:21 AM',
#    u'latitude': 40.71870987,
#    u'location': u'',
#    u'longitude': -74.0090009,
#    u'postalCode': u'',
#    u'stAddress1': u'Harrison St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Harrison St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 250,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:42 AM',
#    u'latitude': 40.72456089,
#    u'location': u'',
#    u'longitude': -73.99565293,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & Jersey St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & Jersey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 40},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 251,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:16 AM',
#    u'latitude': 40.72317958,
#    u'location': u'',
#    u'longitude': -73.99480012,
#    u'postalCode': u'',
#    u'stAddress1': u'Mott St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'Mott St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 252,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:10 AM',
#    u'latitude': 40.73226398,
#    u'location': u'',
#    u'longitude': -73.99852205,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Washington Sq',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Washington Sq',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 37,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 253,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:12 AM',
#    u'latitude': 40.73543934,
#    u'location': u'',
#    u'longitude': -73.99453948,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 254,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:49 AM',
#    u'latitude': 40.73532427,
#    u'location': u'',
#    u'longitude': -73.99800419,
#    u'postalCode': u'',
#    u'stAddress1': u'W 11 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 11 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 257,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:06 AM',
#    u'latitude': 40.71939226,
#    u'location': u'',
#    u'longitude': -74.00247214,
#    u'postalCode': u'',
#    u'stAddress1': u'Lispenard St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Lispenard St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 258,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:26 AM',
#    u'latitude': 40.68940747,
#    u'location': u'',
#    u'longitude': -73.96885458,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & Vanderbilt Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & Vanderbilt Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 259,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:48 AM',
#    u'latitude': 40.70122128,
#    u'location': u'',
#    u'longitude': -74.01234218,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Whitehall St',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Whitehall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 34,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 260,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:48 AM',
#    u'latitude': 40.70365182,
#    u'location': u'',
#    u'longitude': -74.01167797,
#    u'postalCode': u'',
#    u'stAddress1': u'Broad St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Broad St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 261,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:56 AM',
#    u'latitude': 40.69474881,
#    u'location': u'',
#    u'longitude': -73.98362464,
#    u'postalCode': u'',
#    u'stAddress1': u'Johnson St & Gold St',
#    u'stAddress2': u'',
#    u'stationName': u'Johnson St & Gold St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 262,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:31 AM',
#    u'latitude': 40.6917823,
#    u'location': u'',
#    u'longitude': -73.9737299,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Park',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 263,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:47 AM',
#    u'latitude': 40.71729,
#    u'location': u'',
#    u'longitude': -73.996375,
#    u'postalCode': u'',
#    u'stAddress1': u'Elizabeth St & Hester St',
#    u'stAddress2': u'',
#    u'stationName': u'Elizabeth St & Hester St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 264,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:40 AM',
#    u'latitude': 40.70706456,
#    u'location': u'',
#    u'longitude': -74.00731853,
#    u'postalCode': u'',
#    u'stAddress1': u'Maiden Ln & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'Maiden Ln & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 265,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:35 AM',
#    u'latitude': 40.72229346,
#    u'location': u'',
#    u'longitude': -73.99147535,
#    u'postalCode': u'',
#    u'stAddress1': u'Stanton St & Chrystie St',
#    u'stAddress2': u'',
#    u'stationName': u'Stanton St & Chrystie St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 266,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:16 AM',
#    u'latitude': 40.72368361,
#    u'location': u'',
#    u'longitude': -73.97574813,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 55,
#    u'city': u'',
#    u'id': 267,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:06 AM',
#    u'latitude': 40.75097711,
#    u'location': u'',
#    u'longitude': -73.98765428,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 36 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 36 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 57},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 268,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:37 AM',
#    u'latitude': 40.71910537,
#    u'location': u'',
#    u'longitude': -73.99973337,
#    u'postalCode': u'',
#    u'stAddress1': u'Howard St & Centre St',
#    u'stAddress2': u'',
#    u'stationName': u'Howard St & Centre St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 270,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:38 AM',
#    u'latitude': 40.69308257,
#    u'location': u'',
#    u'longitude': -73.97178913,
#    u'postalCode': u'',
#    u'stAddress1': u'Adelphi St & Myrtle Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Adelphi St & Myrtle Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 274,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:28 AM',
#    u'latitude': 40.68691865,
#    u'location': u'',
#    u'longitude': -73.976682,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 275,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:51 AM',
#    u'latitude': 40.68650065,
#    u'location': u'',
#    u'longitude': -73.96563307,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Greene Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Greene Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 276,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:24 AM',
#    u'latitude': 40.71748752,
#    u'location': u'',
#    u'longitude': -74.0104554,
#    u'postalCode': u'',
#    u'stAddress1': u'Duane St & Greenwich St',
#    u'stAddress2': u'',
#    u'stationName': u'Duane St & Greenwich St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 278,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:05 AM',
#    u'latitude': 40.69766564,
#    u'location': u'',
#    u'longitude': -73.98476437,
#    u'postalCode': u'',
#    u'stAddress1': u'Concord St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Concord St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 279,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:39 AM',
#    u'latitude': 40.707873,
#    u'location': u'',
#    u'longitude': -74.00167,
#    u'postalCode': u'',
#    u'stAddress1': u'Peck Slip & Front St',
#    u'stAddress2': u'',
#    u'stationName': u'Peck Slip & Front St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 280,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:44 AM',
#    u'latitude': 40.73331967,
#    u'location': u'',
#    u'longitude': -73.99510132,
#    u'postalCode': u'',
#    u'stAddress1': u'E 10 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 10 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 57,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 281,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:05 AM',
#    u'latitude': 40.7643971,
#    u'location': u'',
#    u'longitude': -73.97371465,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand Army Plaza & Central Park S',
#    u'stAddress2': u'',
#    u'stationName': u'Grand Army Plaza & Central Park S',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 282,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:29 AM',
#    u'latitude': 40.70827295,
#    u'location': u'',
#    u'longitude': -73.96834101,
#    u'postalCode': u'',
#    u'stAddress1': u'Kent Ave & S 11 St',
#    u'stAddress2': u'',
#    u'stationName': u'Kent Ave & S 11 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 40,
#    u'city': u'',
#    u'id': 284,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:40 AM',
#    u'latitude': 40.7390169121,
#    u'location': u'',
#    u'longitude': -74.0026376103,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich Ave & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich Ave & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 33,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 285,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:18 AM',
#    u'latitude': 40.73454567,
#    u'location': u'',
#    u'longitude': -73.99074142,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & E 14 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & E 14 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 289,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:48 AM',
#    u'latitude': 40.6845683,
#    u'location': u'',
#    u'longitude': -73.95881081,
#    u'postalCode': u'',
#    u'stAddress1': u'Monroe St & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Monroe St & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 290,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:52 AM',
#    u'latitude': 40.76020258,
#    u'location': u'',
#    u'longitude': -73.96478473,
#    u'postalCode': u'',
#    u'stAddress1': u'2 Ave & E 58 St',
#    u'stAddress2': u'',
#    u'stationName': u'2 Ave & E 58 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 291,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:49 AM',
#    u'latitude': 40.713126,
#    u'location': u'',
#    u'longitude': -73.984844,
#    u'postalCode': u'',
#    u'stAddress1': u'Madison St & Montgomery St',
#    u'stAddress2': u'',
#    u'stationName': u'Madison St & Montgomery St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 34,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 293,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:44 AM',
#    u'latitude': 40.73028666,
#    u'location': u'',
#    u'longitude': -73.9907647,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 294,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-28 10:15:50 AM',
#    u'latitude': 40.73049393,
#    u'location': u'',
#    u'longitude': -73.9957214,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Square E',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Square E',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 3},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 295,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:40 AM',
#    u'latitude': 40.71406667,
#    u'location': u'',
#    u'longitude': -73.99293911,
#    u'postalCode': u'',
#    u'stAddress1': u'Pike St & E Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Pike St & E Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 296,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:33 AM',
#    u'latitude': 40.71413089,
#    u'location': u'',
#    u'longitude': -73.9970468,
#    u'postalCode': u'',
#    u'stAddress1': u'Division St & Bowery',
#    u'stAddress2': u'',
#    u'stationName': u'Division St & Bowery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 297,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:29 AM',
#    u'latitude': 40.734232,
#    u'location': u'',
#    u'longitude': -73.986923,
#    u'postalCode': u'',
#    u'stAddress1': u'E 15 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 15 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 298,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:33 AM',
#    u'latitude': 40.68683208,
#    u'location': u'',
#    u'longitude': -73.9796772,
#    u'postalCode': u'',
#    u'stAddress1': u'3 Ave & Schermerhorn St',
#    u'stAddress2': u'',
#    u'stationName': u'3 Ave & Schermerhorn St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 53,
#    u'city': u'',
#    u'id': 300,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:02 AM',
#    u'latitude': 40.728145,
#    u'location': u'',
#    u'longitude': -73.990214,
#    u'postalCode': u'',
#    u'stAddress1': u'Shevchenko Pl & E 7 St',
#    u'stAddress2': u'',
#    u'stationName': u'Shevchenko Pl & E 7 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 301,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:11 AM',
#    u'latitude': 40.72217444,
#    u'location': u'',
#    u'longitude': -73.98368779,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue B',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue B',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 302,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:21 AM',
#    u'latitude': 40.72082834,
#    u'location': u'',
#    u'longitude': -73.97793172,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 30,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 303,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:52 AM',
#    u'latitude': 40.72362738,
#    u'location': u'',
#    u'longitude': -73.99949601,
#    u'postalCode': u'',
#    u'stAddress1': u'Mercer St & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Mercer St & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 33,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 304,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:51 AM',
#    u'latitude': 40.70463334,
#    u'location': u'',
#    u'longitude': -74.01361706,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & Battery Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & Battery Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 305,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:07 AM',
#    u'latitude': 40.76095756,
#    u'location': u'',
#    u'longitude': -73.96724467,
#    u'postalCode': u'',
#    u'stAddress1': u'E 58 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 58 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 306,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:28 AM',
#    u'latitude': 40.70823502,
#    u'location': u'',
#    u'longitude': -74.00530063,
#    u'postalCode': u'',
#    u'stAddress1': u'Cliff St & Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Cliff St & Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 307,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:46 AM',
#    u'latitude': 40.71427487,
#    u'location': u'',
#    u'longitude': -73.98990025,
#    u'postalCode': u'',
#    u'stAddress1': u'Canal St & Rutgers St',
#    u'stAddress2': u'',
#    u'stationName': u'Canal St & Rutgers St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 308,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:00 AM',
#    u'latitude': 40.71307916,
#    u'location': u'',
#    u'longitude': -73.99851193,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Oliver St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Oliver St',
#    u'statusKey': 1,
# ...
#    u'longitude': -74.0321082,
#    u'postalCode': u'',
#    u'stAddress1': u'Newport Pkwy',
#    u'stAddress2': u'',
#    u'stationName': u'Newport Pkwy',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 3200,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:35 AM',
#    u'latitude': 40.7111305,
#    u'location': u'',
#    u'longitude': -74.0788855,
#    u'postalCode': u'',
#    u'stAddress1': u'MLK Light Rail',
#    u'stAddress2': u'',
#    u'stationName': u'MLK Light Rail',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 3201,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:55 AM',
#    u'latitude': 40.737711,
#    u'location': u'',
#    u'longitude': -74.066921,
#    u'postalCode': u'',
#    u'stAddress1': u'Dey St',
#    u'stAddress2': u'',
#    u'stationName': u'Dey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 3202,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:20 AM',
#    u'latitude': 40.7272235,
#    u'location': u'',
#    u'longitude': -74.0337589,
#    u'postalCode': u'',
#    u'stAddress1': u'Newport PATH',
#    u'stAddress2': u'',
#    u'stationName': u'Newport PATH',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 3203,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:06 AM',
#    u'latitude': 40.727595966,
#    u'location': u'',
#    u'longitude': -74.044247311,
#    u'postalCode': u'',
#    u'stAddress1': u'Hamilton Park',
#    u'stAddress2': u'',
#    u'stationName': u'Hamilton Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 3205,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:53 AM',
#    u'latitude': 40.7165271,
#    u'location': u'',
#    u'longitude': -74.049425,
#    u'postalCode': u'',
#    u'stAddress1': u'JC Medical Center',
#    u'stAddress2': u'',
#    u'stationName': u'JC Medical Center',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 3206,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:57 AM',
#    u'latitude': 40.7311689,
#    u'location': u'',
#    u'longitude': -74.0575736,
#    u'postalCode': u'',
#    u'stAddress1': u'Hilltop',
#    u'stAddress2': u'',
#    u'stationName': u'Hilltop',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 3207,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:36 AM',
#    u'latitude': 40.7376037,
#    u'location': u'',
#    u'longitude': -74.0524783,
#    u'postalCode': u'',
#    u'stAddress1': u'Oakland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Oakland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3209,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:13 AM',
#    u'latitude': 40.7241765,
#    u'location': u'',
#    u'longitude': -74.0506564,
#    u'postalCode': u'',
#    u'stAddress1': u'Brunswick St',
#    u'stAddress2': u'',
#    u'stationName': u'Brunswick St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 3210,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:59 AM',
#    u'latitude': 40.742677141,
#    u'location': u'',
#    u'longitude': -74.051788633,
#    u'postalCode': u'',
#    u'stAddress1': u'Pershing Field',
#    u'stAddress2': u'',
#    u'stationName': u'Pershing Field',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 3211,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:38 AM',
#    u'latitude': 40.72152515,
#    u'location': u'',
#    u'longitude': -74.046304543,
#    u'postalCode': u'',
#    u'stAddress1': u'Newark Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Newark Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 3212,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:01 AM',
#    u'latitude': 40.734785818,
#    u'location': u'',
#    u'longitude': -74.050443636,
#    u'postalCode': u'',
#    u'stAddress1': u'Christ Hospital',
#    u'stAddress2': u'',
#    u'stationName': u'Christ Hospital',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3213,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:49 AM',
#    u'latitude': 40.71848892,
#    u'location': u'',
#    u'longitude': -74.047726625,
#    u'postalCode': u'',
#    u'stAddress1': u'Van Vorst Park',
#    u'stAddress2': u'',
#    u'stationName': u'Van Vorst Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3214,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:48 AM',
#    u'latitude': 40.7127742,
#    u'location': u'',
#    u'longitude': -74.0364857,
#    u'postalCode': u'',
#    u'stAddress1': u'Essex Light Rail',
#    u'stAddress2': u'',
#    u'stationName': u'Essex Light Rail',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3215,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:58 AM',
#    u'latitude': 40.7467299,
#    u'location': u'',
#    u'longitude': -74.0492509,
#    u'postalCode': u'',
#    u'stAddress1': u'Central Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Central Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 3216,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:48 AM',
#    u'latitude': 40.6970299,
#    u'location': u'',
#    u'longitude': -74.0969366,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Park',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3217,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:36 AM',
#    u'latitude': 40.698650544,
#    u'location': u'',
#    u'longitude': -74.082079678,
#    u'postalCode': u'',
#    u'stAddress1': u'Bayside Park',
#    u'stAddress2': u'',
#    u'stationName': u'Bayside Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3220,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:01 AM',
#    u'latitude': 40.73496102001,
#    u'location': u'',
#    u'longitude': -74.059503078461,
#    u'postalCode': u'',
#    u'stAddress1': u'5 Corners Library',
#    u'stAddress2': u'',
#    u'stationName': u'5 Corners Library',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 3221,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:19 AM',
#    u'latitude': 40.743,
#    u'location': u'',
#    u'longitude': -73.93561,
#    u'postalCode': u'',
#    u'stAddress1': u'47 Ave & 31 St',
#    u'stAddress2': u'',
#    u'stationName': u'47 Ave & 31 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 3222,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:37 AM',
#    u'latitude': 40.685159599892,
#    u'location': u'',
#    u'longitude': -73.97711366415,
#    u'postalCode': u'',
#    u'stAddress1': u'Hanson Pl & St Felix St',
#    u'stAddress2': u'',
#    u'stationName': u'Hanson Pl & St Felix St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 54,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3223,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:36:08 AM',
#    u'latitude': 40.758996559605,
#    u'location': u'',
#    u'longitude': -73.968653976917,
#    u'postalCode': u'',
#    u'stAddress1': u'E 55 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 55 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 34,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 3224,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:11 AM',
#    u'latitude': 40.739973541034,
#    u'location': u'',
#    u'longitude': -74.005138725042,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3225,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:23 AM',
#    u'latitude': 40.7236589,
#    u'location': u'',
#    u'longitude': -74.0641943,
#    u'postalCode': u'',
#    u'stAddress1': u'Baldwin at Montgomery',
#    u'stAddress2': u'',
#    u'stationName': u'Baldwin at Montgomery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 3226,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:56 AM',
#    u'latitude': 40.78275,
#    u'location': u'',
#    u'longitude': -73.97137,
#    u'postalCode': u'',
#    u'stAddress1': u'W 82 St & Central Park West',
#    u'stAddress2': u'',
#    u'stationName': u'W 82 St & Central Park West',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3229,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:33:46 AM',
#    u'latitude': 40.680617684555,
#    u'location': u'',
#    u'longitude': -73.946249485016,
#    u'postalCode': u'',
#    u'stAddress1': u'Marcy Ave & MacDonough St',
#    u'stAddress2': u'',
#    u'stationName': u'Marcy Ave & MacDonough St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 3230,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:55 AM',
#    u'latitude': 40.751283596962,
#    u'location': u'',
#    u'longitude': -73.996924459934,
#    u'postalCode': u'',
#    u'stAddress1': u'Penn Station Valet',
#    u'stAddress2': u'',
#    u'stationName': u'Penn Station Valet',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 7},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 3231,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:33 AM',
#    u'latitude': 40.767800801481,
#    u'location': u'',
#    u'longitude': -73.965920805931,
#    u'postalCode': u'',
#    u'stAddress1': u'E 67 St & Park Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 67 St & Park Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 3232,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:32:33 AM',
#    u'latitude': 40.689621887903,
#    u'location': u'',
#    u'longitude': -73.983042687178,
#    u'postalCode': u'',
#    u'stAddress1': u'Bond St & Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Bond St & Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3233,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:22 AM',
#    u'latitude': 40.757245679117,
#    u'location': u'',
#    u'longitude': -73.978059142828,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 45,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 3234,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:13 AM',
#    u'latitude': 40.751593684511,
#    u'location': u'',
#    u'longitude': -73.980431556702,
#    u'postalCode': u'',
#    u'stAddress1': u'E 40 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 40 St & Madison Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 3235,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:34:41 AM',
#    u'latitude': 40.752165280622,
#    u'location': u'',
#    u'longitude': -73.979921936989,
#    u'postalCode': u'',
#    u'stAddress1': u'E 41 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 41 St & Madison Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 3236,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:44 AM',
#    u'latitude': 40.758984813996,
#    u'location': u'',
#    u'longitude': -73.993799686432,
#    u'postalCode': u'',
#    u'stAddress1': u'PABT Valet',
#    u'stAddress2': u'',
#    u'stationName': u'PABT Valet',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 9},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 3237,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-11-03 10:35:25 AM',
#    u'latitude': 40.753833434376,
#    u'location': u'',
#    u'longitude': -73.942676782608,
#    u'postalCode': u'',
#    u'stAddress1': u'21 St & 41 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'21 St & 41 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25}]}

# %% [markdown]
# You can see the data is formatted into what's called JavaScript Object Notation (JSON). This is a standardized way of formatting data that helps display not only the values but the structure of the data, something that gets lost when data is displayed in a CSV. You access elements in a JSON in the same way you access items in a dictionary, which means you reference values by their key.
# To get a list of keys, you can use the keys() function, which will return a list of the keys available at that level of the JSON. You can then begin navigating down the structure of the JSON:

# %%
nyc_bike.json().keys()
# Out:
# [u'executionTime', u'stationBeanList']

# %%
# If you look at the "executionTime" r.json()['executionTime'], you'll see a string with the time the file was created.
print nyc_bike.json()['executionTime']
# Out:
# 2015-11-03 10:36:09 AM

# %%
# If you look at the "stationBeanList" (r.json()['stationBeanList']), you'll see the list of stations. 
print nyc_bike.json()['stationBeanList']
# Out:
# [{u'availableDocks': 37, u'totalDocks': 39, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -73.99392888, u'lastCommunicationTime': u'2015-11-03 10:35:45 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'W 52 St & 11 Ave', u'stationName': u'W 52 St & 11 Ave', u'landMark': u'', u'latitude': 40.76727216, u'statusKey': 1, u'availableBikes': 1, u'id': 72, u'location': u''}, {u'availableDocks': 11, u'totalDocks': 33, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -74.00666661, u'lastCommunicationTime': u'2015-11-03 10:35:39 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'Franklin St & W Broadway', u'stationName': u'Franklin St & W Broadway', u'landMark': u'', u'latitude': 40.71911552, u'statusKey': 1, u'availableBikes': 22, u'id': 79, u'location': u''}, {u'availableDocks': 10, u'totalDocks': 27, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -74.00016545, u'lastCommunicationTime': u'2015-11-03 10:33:17 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'St James Pl & Pearl St', u'stationName': u'St James Pl & Pearl St', u'landMark': u'', u'latitude': 40.71117416, u'statusKey': 1, u'availableBikes': 17, u'id': 82, u'location': u''}, {u'availableDocks': 47, u'totalDocks': 62, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -73.97632328, u'lastCommunicationTime': u'2015-11-03 10:33:16 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'Atlantic Ave & Fort Greene Pl', u'stationName': u'Atlantic Ave & Fort Greene Pl', u'landMark': u'', u'latitude': 40.68382604, u'statusKey': 1, u'availableBikes': 15, u'id': 83, u'location': u''}, {u'availableDocks': 31, u'totalDocks': 39, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -74.00149746, u'lastCommunicationTime': u'2015-11-03 10:32:21 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'W 17 St & 8 Ave', u'stationName': u'W 17 St & 8 Ave', u'landMark': u'', u'latitude': 40.74177603, u'statusKey': 1, u'availableBikes': 8, u'id': 116, u'location': u''}, {u'availableDocks': 16, u'totalDocks': 19, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -73.97803415, u'lastCommunicationTime': u'2015-11-03 10:35:58 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'Park Ave & St Edwards St', u'stationName': u'Park Ave & St Edwards St', u'landMark': u'', u'latitude': 40.69608941, u'statusKey': 1, u'availableBikes': 3, u'id': 119, u'location': u''}, {u'availableDocks': 16, u'totalDocks': 19, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -73.95928168, u'lastCommunicationTime': u'2015-11-03 10:33:22 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'Lexington Ave & Classon Ave', u'stationName': u'Lexington Ave & Classon Ave', u'landMark': u'', u'latitude': 40.68676793, u'statusKey': 1, u'availableBikes': 3, u'id': 120, u'location': u''}, {u'availableDocks': 0, u'totalDocks': 31, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -74.00674436, u'lastCommunicationTime': u'2015-11-03 10:35:07 AM', u'postalCode': u'', u'statusValue': u'In Service', u'testStation': False, u'stAddress1': u'Barrow St & Hudson St', u'stationName': u'Barrow St & Hudson St', u'landMark': u'', u'latitude': 40.73172428, u'statusKey': 1, u'availableBikes': 30, u'id': 127, u'location': u''}, {u'availableDocks': 28, u'totalDocks': 29, u'city': u'', u'altitude': u'', u'stAddress2': u'', u'longitude': -74.00297088, u'lastCommunicationTime': u'2015-09-24 09:23:40 AM', u'postalCode': u'', u'statusValue': u'Not In Service', u'testStation': False, u'stAddress1': u'MacDougal St & Prince St', u'stationName': u'MacDougal St & Prince St', u'landMark': u'', u'latitude': 40.72710258, u'statusKey': 3,  ...

# %% [markdown]
# <b>Question:</b> This returns everything - not just the station names; it looks like this is a result of 'stationBeanList' being a key with the corresponding values being all of the fields except 'executionTime'. Thus, when you pull that key, it returns everything. Please confirm if this is a mistake by Thinkful or if I'm making a mistake.
# <b>Update:</b> “This returns everything - not just the station names…“: This is the lesson not being clear enough. stationBeanList is a key, and its associated value is a list, of which each element is a dictionary with one station’s information. Printing it will print each of the elements it contains, not just a particular field from each element. If you want to extract just one particular field, you could try using:
# <i>[x['stationName'] for x in nyc_bikes.json()[stationBeanList]</i>

# %%
# To get the number of docks, use the len() function (len(r.json()['stationBeanList'])).
print len(nyc_bike.json()['stationBeanList'])
# Out:
# 512

# %% [markdown]
# You can test that you have all the fields (important for setting up a database) by running the data through a loop and gathering all the fields together:

# %%
key_list = [] #unique list of keys for each station listing
for station in nyc_bike.json()['stationBeanList']:
    for k in station.keys():
        if k not in key_list:
            key_list.append(k)
            
key_list
# Out:
# [u'availableDocks',
#  u'totalDocks',
#  u'city',
#  u'altitude',
#  u'stAddress2',
#  u'longitude',
#  u'lastCommunicationTime',
#  u'postalCode',
#  u'statusValue',
#  u'testStation',
#  u'stAddress1',
#  u'stationName',
#  u'landMark',
#  u'latitude',
#  u'statusKey',
#  u'availableBikes',
#  u'id',
#  u'location']

# %% [markdown]
# Remember values in r.json()['stationBeanList'] are a list and you can reference the elements like any other list by using the index. To get the first element, you type:

# %%
nyc_bike.json()['stationBeanList'][0]
# Out:
# {u'altitude': u'',
#  u'availableBikes': 1,
#  u'availableDocks': 37,
#  u'city': u'',
#  u'id': 72,
#  u'landMark': u'',
#  u'lastCommunicationTime': u'2015-11-03 10:35:45 AM',
#  u'latitude': 40.76727216,
#  u'location': u'',
#  u'longitude': -73.99392888,
#  u'postalCode': u'',
#  u'stAddress1': u'W 52 St & 11 Ave',
#  u'stAddress2': u'',
#  u'stationName': u'W 52 St & 11 Ave',
#  u'statusKey': 1,
#  u'statusValue': u'In Service',
#  u'testStation': False,
#  u'totalDocks': 39}

# %% [markdown]
# ### Getting Data into a DataFrame

# %% [markdown]
# Now that you've explored the data a bit and understand its structure, you can convert the data into a pandas DataFrame. Because it's in JSON format, you have to do something a little different to import it:

# %%
from pandas.io.json import json_normalize

nyc_bike_frame = json_normalize(nyc_bike.json()['stationBeanList'])
nyc_bike_frame.head()
# Out:
#   altitude  availableBikes  availableDocks city   id landMark  \
# 0                        1              37        72
# 1                       22              11        79
# 2                       17              10        82
# 3                       15              47        83
# 4                        8              31       116
#
#     lastCommunicationTime   latitude location  longitude postalCode  \
# 0  2015-11-03 10:35:45 AM  40.767272          -73.993929
# 1  2015-11-03 10:35:39 AM  40.719116          -74.006667
# 2  2015-11-03 10:33:17 AM  40.711174          -74.000165
# 3  2015-11-03 10:33:16 AM  40.683826          -73.976323
# 4  2015-11-03 10:32:21 AM  40.741776          -74.001497
#
#                       stAddress1 stAddress2                    stationName  \
# 0               W 52 St & 11 Ave                          W 52 St & 11 Ave
# 1       Franklin St & W Broadway                  Franklin St & W Broadway
# 2         St James Pl & Pearl St                    St James Pl & Pearl St
# 3  Atlantic Ave & Fort Greene Pl             Atlantic Ave & Fort Greene Pl
# 4                W 17 St & 8 Ave                           W 17 St & 8 Ave
#
#    statusKey statusValue testStation  totalDocks
# 0          1  In Service       False          39
# 1          1  In Service       False          33
# 2          1  In Service       False          27
# 3          1  In Service       False          62
# 4          1  In Service       False          39

# %% [markdown]
# Notice we're taking the <u>stationBeanList and passing values associated with it to pandas to create a DataFrame out of the data instead of the whole JSON.</u> We end up with a standard DataFrame like we've used in the past lessons.

# %% [markdown]
# ### Checking the Range of Values

# %% [markdown]
# Let's look at the range of values for each attribute, starting with the available bikes:

# %%
nyc_bike_frame['availableBikes'].hist()
plt.show()

# %% [markdown]
# Look at the range of total docks:

# %%
nyc_bike_frame['totalDocks'].hist()
plt.show()

# %% [markdown]
# These distributions differ because available bikes is a real time changing data point where as total docks is a fixed variable (at least in the short term). Total docks will not change unless more docks are added at the station.

# %% [markdown]
# ### Summing up

# %% [markdown]
# We have a simple JSON structure:
#
# ![](files/nycbike4.jpg)
#
# That we navigated with using the keys() function to explore the various levels (in this case 2 levels below the root level) and we have a good idea of the value ranges. We have a sense of the values we're dealing with.

# %% [markdown]
# ## Challenge

# %% [markdown]
# <b>1. Explore the other data variables. Are there any test stations? How many stations are "In Service"? How many are "Not In Service"? Any other interesting variables values that need to be accounted for?</b>

# %%
# Test Stations:
print nyc_bike_frame.testStation.value_counts()
# Out:
# False    512
# dtype: int64

# %% [markdown]
# No - there aren't any test stations in this dataset.

# %%
# Stations in-service vs. out of service:
print nyc_bike_frame.statusValue.value_counts()
# Out:
# In Service        493
# Not In Service     19
# dtype: int64

# %% [markdown]
# <b>Note:</b> We want to ensure there are no duplicate stations in here that could skew this result. Check for duplicates:

# %%
# Calling .head() will show the top counts; if there are any above 1 we know their are duplicate stations in the data:
nyc_bike_frame.groupby(['stationName'])['stationName'].count().head()
# Out:
# stationName
# 1 Ave & E 15 St    1
# 1 Ave & E 18 St    1
# 1 Ave & E 30 St    1
# 1 Ave & E 44 St    1
# 1 Ave & E 62 St    1
# Name: stationName, dtype: int64

# %% [markdown]
# There are no duplicate stations. Thus, there are 488 'In Service' and 22 'Not in Service' stations in our dataset.
# <b>NOTE:</b> These are real time datasets, so they are subject to change if you run the scripts at different times.

# %% [markdown]
# Custom Function: It is useful to know quickly the number of unique values in each column of a dataframe. Columns with many unique values can be difficult to model and columns with only one or very few unique entries often don't add value to a model. The below function takes a dataframe and returns the number of unique entries for each column; allowing us to set a value for what we consider to be small for the given dataset we are working with.

# %%
def unique_entry_count(dataframe, small_value):
    '''
    takes a dataframe and returns the columns with the number of unique entries for that specific column; assigning values of 
    one_only, small or large; user chooses the unique count that will determine small / large in function parameters
    '''
    entry_list = [] #list that will contain the raw unique counts for each column in the dataframe
    
    columns = dataframe.columns #list of the dataframe's columns; to be used in the append portion to call to the correct column name and
    #in for the index in the new dataframe
    cols = ['unqiue_entries'] #the column name for the new dataframe
    col_len = len(columns)
    
    for i in range(col_len):
        entry_list.append(dataframe[columns[i]].value_counts().count()) #iterates through each column and counts the number of unique
        #entries and appends that final figure to the entry_list

    unique_entry_frame = pd.DataFrame(entry_list, index=columns, columns=cols) #creates new dataframe
    unique_entry_frame['size'] = unique_entry_frame['unqiue_entries'].apply(lambda x: 'one_only' if x == 1 else 'small' \
                                                                      if x < small_value else 'large')
    #based on number of unique entries; applies 'size' to that particular column
    
    return unique_entry_frame #returns new dataframe that will be used for next group of functions

# %%
# Set small value to 3
nyc_bike_column_counts = unique_entry_count(nyc_bike_frame, 3)
nyc_bike_column_counts
# Out:
#                        unqiue_entries      size
# altitude                            1  one_only
# availableBikes                     52     large
# availableDocks                     59     large
# city                                1  one_only
# id                                512     large
# landMark                            1  one_only
# lastCommunicationTime             213     large
# latitude                          512     large
# location                            1  one_only
# longitude                         512     large
# postalCode                          1  one_only
# stAddress1                        512     large
# stAddress2                          1  one_only
# stationName                       512     large
# statusKey                           2     small
# statusValue                         2     small
# testStation                         1  one_only
# totalDocks                         51     large

# %% [markdown]
# There are a lot of columns with only one unique value or they are completely empty. We don't need these columns - we can delete them:

# %%
# create list of the one value columns:
nyc_one_value = nyc_bike_column_counts[(nyc_bike_column_counts['size'] == 'one_only')]
delete_list = nyc_one_value.index

# drop those columns in the original dataframe:
nyc_bike_frame = nyc_bike_frame.drop(delete_list, axis = 1)

#return original dataframe with deleted columns:
nyc_bike_frame.head(2)
# Out:
#    availableBikes  availableDocks  id   lastCommunicationTime   latitude  \
# 0               1              37  72  2015-11-03 10:35:45 AM  40.767272
# 1              22              11  79  2015-11-03 10:35:39 AM  40.719116
#
#    longitude                stAddress1               stationName  statusKey  \
# 0 -73.993929          W 52 St & 11 Ave          W 52 St & 11 Ave          1
# 1 -74.006667  Franklin St & W Broadway  Franklin St & W Broadway          1
#
#   statusValue  totalDocks
# 0  In Service          39
# 1  In Service          33

# %% [markdown]
# Already, we have a cleaner dataset to work with. Two other columns worth a look at this time would be the columns with 2 unique values:

# %%
print nyc_bike_frame.statusKey.value_counts()
print nyc_bike_frame.statusValue.value_counts()
# Out:
# 1    493
# 3     19
# dtype: int64
# In Service        493
# Not In Service     19
# dtype: int64

# %% [markdown]
# I'm not sure what statusKey is describing, so I'll leave it for now. 'statusValue' could be important, it will stay as well.

# %% [markdown]
# The columns with 511<i>(subject to change depending on when script is run)</i> unique entries appear to be ID related; letting us know what station the data is referring to for that row. Latitude and Longtitude are important for location, but ID, StationName and street address are worth a quick look:

# %%
print nyc_bike_frame['id'].value_counts().head()
print nyc_bike_frame['stAddress1'].value_counts().head()
print nyc_bike_frame['stationName'].value_counts().head()
# Out:
# 3071    1
# 3070    1
# 173     1
# 174     1
# 195     1
# dtype: int64
# Mercer St & Bleecker St     1
# Bushwick Ave & Powers St    1
# W 45 St & 6 Ave             1
# Columbus Ave & W 72 St      1
# 6 Ave & Canal St            1
# dtype: int64
# Mercer St & Bleecker St     1
# Bushwick Ave & Powers St    1
# W 45 St & 6 Ave             1
# Columbus Ave & W 72 St      1
# 6 Ave & Canal St            1
# dtype: int64

# %% [markdown]
# We can see that these three columns are repeating the same information (id is a code that refers to the stationName). We will keep stationName and id (could be important later) and remove the address:

# %%
nyc_bike_frame = nyc_bike_frame.drop(['stAddress1'], axis=1)
nyc_bike_frame.head(2)
# Out:
#    availableBikes  availableDocks  id   lastCommunicationTime   latitude  \
# 0               1              37  72  2015-11-03 10:35:45 AM  40.767272
# 1              22              11  79  2015-11-03 10:35:39 AM  40.719116
#
#    longitude               stationName  statusKey statusValue  totalDocks
# 0 -73.993929          W 52 St & 11 Ave          1  In Service          39
# 1 -74.006667  Franklin St & W Broadway          1  In Service          33

# %% [markdown]
# We have now a much cleaner and more meaningful dataset with the unncessary columns removed. We will decide later if 'statusKey' is required.

# %% [markdown]
# <b>2. What is the mean number of bikes in a dock? What is the median? How does this change if we remove the stations that aren't in service?</b>

# %%
# Assuming mean and median number of bikes in a dock refers to the number of availableBikes.
nyc_bike_mean = nyc_bike_frame['availableBikes'].mean()
nyc_bike_median = nyc_bike_frame['availableBikes'].median()

print 'Available Bike Mean (all stations): ', nyc_bike_mean
print 'Available Bike Median (all stations): ',nyc_bike_median
print 'Number of Stations Included: ', len(nyc_bike_frame)
print ''

# Remove stations not in service:
nyc_bike_frame_inService = nyc_bike_frame[(nyc_bike_frame['statusValue'] == 'In Service')]

nyc_bike_inService_mean = nyc_bike_frame_inService['availableBikes'].mean()
nyc_bike_inService_median = nyc_bike_frame_inService['availableBikes'].median()

print 'Available Bike Mean (In Service stations): ', nyc_bike_inService_mean
print 'Available Bike Median (In Service stations): ',nyc_bike_inService_median
print 'Number of Stations Included: ', len(nyc_bike_frame_inService)
# Out:
# Available Bike Mean (all stations):  11.33984375
# Available Bike Median (all stations):  5.0
# Number of Stations Included:  512
#
# Available Bike Mean (In Service stations):  11.7768762677
# Available Bike Median (In Service stations):  6.0
# Number of Stations Included:  493

# %% [markdown]
# The mean and median do not change significantly if you remove out of service stations.

# %% [markdown]
# <b>Note: Here is an alternate way of calculating mean and median without having to create a new dataframe. You would add a simple conditional (a series of boolean, or True and False, values) to filter on the DataFrame (only the rows for the True values are in the result):</b>

# %%
condition = (nyc_bike_frame['statusValue'] == 'In Service')
print nyc_bike_frame[condition]['availableBikes'].mean()

# We can put the condition right into the statement making it one line:
print nyc_bike_frame[nyc_bike_frame['statusValue'] == 'In Service']['availableBikes'].mean()
# Out:
# 11.7768762677
# 11.7768762677

# %% [markdown]
# <b>This method is prefered over the original method. It's cleaner and easier to implement.</b>

# %% [markdown]
# ## Storing Data in SQLite

# %% [markdown]
# While often code can be developed iteratively (meaning you create code by making small changes that build on each other), designing a database requires more thoughtful planning, even one as simple as a SQLite database. We know now the structure of the data, which is important for creating the schema we'll be using in SQLite.
#
# After going through the data more, you'll find that not every field seems to be used. Often this is because developers envision functionality that isn't yet built. In this case, no station has a value in the "landMark" field and only two have an entry in the "location" field. Someone likely envisoned these providing more information that was actually necessary when the system was activated but may, in the future, carry important information.
#
# <b>Note:</b> In some cases, JSON files will only include the attributes of an instance for which there is a value. In this case, if there isn't a landmark, the attribute landMark may not be present in order to minimize the size of the file.
#
# Most of these values don't change over time. The only fields likely to change are the availableBikes, availableDocks, statusValue, and the statusKey. In this case, since our goal is to record the number of bikes available every minute for an hour across all of New York City, we're primarily interested in the number of available bikes, but we want to keep all this reference information as well.
#
# In order to capture both the changing values and the static reference information, we're going to create a reference table that tells us the information that remains static and a table that collects the changing values.
#
# Our first step is to create a reference table that stores the information that remains static with the station ID (id) number as the key value.
#
# In this case, we'll be storing these values in our reference table:
#
# ![](files/nycbike5.jpg)
#
# Since the number of available docks and available bikes should equal the total docks, we only need to store one of these numbers, in this case, the available bikes. The available docks should be the total docks - the available bikes, but this is a case where we need to be clear about our assumptions and test them if necessary.
# <b>Comment:</b> In this case, our above assumption fails; there are stations where the available bikes plus the available docks does not add up to the total docks. Perhaps there are docks that are in need of repair and are thus, unavailable as a dock. However, we do not know why these numbers are not adding up correctly.

# %% [markdown]
# ### Create SQL database

# %% [markdown]
# The SQL statement we'll be using to create the reference table looks like this:
#
# ![](files/nycbike6.jpg)
#
# <b>Note:</b> My database will be slightly different since I cleaned the data originally differently. The concept remains identical.

# %%
# Create the table to store the data:
import sqlite3 as lite

# %%
con = lite.connect('citi_bike.db') #this creates an empty sqlite database
cur = con.cursor() #once connected to the database, we create a cursor object to perform SQL commands

# %%
#recall dataframe using to create sql database:
nyc_bike_frame.head(1)
# Out:
#    availableBikes  availableDocks  id   lastCommunicationTime   latitude  \
# 0               1              37  72  2015-11-03 10:35:45 AM  40.767272
#
#    longitude       stationName  statusKey statusValue  totalDocks
# 0 -73.993929  W 52 St & 11 Ave          1  In Service          39

# %%
#create table columns with datatypes
with con:
    cur.execute('CREATE TABLE citibike_reference( \
    id INT PRIMARY KEY, \
    totalDocks INT, \
    longitude NUMERIC, \
    stationName TEXT, \
    latitude NUMERIC)')

# %% [markdown]
# We use the <u>'with'</u> keyword as a context manager. At the end of the indented code block, the transaction will commit (be saved) to the database. It's the same result as using con.commit() but generally using 'with' is cleaner and more readable.

# %%
# Populate the table with our nyc_bike_frame:
sql = 'INSERT INTO citibike_reference (id,totalDocks,longitude,stationName,latitude) VALUES (?,?,?,?,?)'
# the number of columns you are going to insert need to match the number of '?' in the VALUES

#for loop to populate values in the database
with con:
    for station in nyc_bike.json()['stationBeanList']: #recall that we need to run the nyc_bike frame (original dataframe)
        #id,totalDocks,longitude,stationName,latitude
        cur.execute(sql,(station['id'],station['totalDocks'],station['longitude'],station['stationName'],station['latitude']))

# %% [markdown]
# The type of SQL query we're using in this case is called a "parameterized query", with ? standing in for values, which we reference in the cur.execute() function. <b>Notice the list of values has to match up otherwise values could be entered into the wrong field.</b> Verification this didn't happen is important to ensure this didn't happen. In most cases, it's better to drop the table and start again rather than try to fix the problem.

# %% [markdown]
# <b>Note:</b> To check to see if our database is being populated correctly we will load the database and verify it's correct:

# %%
print pd.read_sql_query('SELECT * FROM citibike_reference', con).head()
# 'SELECT *' will bring the entire table, 'con' at the end references the connection to the database.
# Out:
#     id  totalDocks  longitude                    stationName   latitude
# 0   72          39 -73.993929               W 52 St & 11 Ave  40.767272
# 1   79          33 -74.006667       Franklin St & W Broadway  40.719116
# 2   82          27 -74.000165         St James Pl & Pearl St  40.711174
# 3   83          62 -73.976323  Atlantic Ave & Fort Greene Pl  40.683826
# 4  116          39 -74.001497                W 17 St & 8 Ave  40.741776

# %% [markdown]
# Our database is being populated correctly. <b>Verified.</b>

# %% [markdown]
# To get multiple readings by minute, the availablebikes table is going to need to be a little different. In this case, the station ID (id) is going to be the column name, but since the column name can't start with a number, you'll need to put a character in front of the number ("").

# %%
#extract the 'id' column from the DataFrame and put them into a list:
station_ids = nyc_bike_frame['id'].tolist() 

#add the '_' to the station name and also add the data type for SQLite
station_ids = ['_' + str(x) + ' INT' for x in station_ids]

print station_ids[:5] 
print len(station_ids)
# Out:
# ['_72 INT', '_79 INT', '_82 INT', '_83 INT', '_116 INT']
# 512

# %% [markdown]
# Create new SQLite database 'available_bikes':

# %%
#in this case, we're concatentating the string and joining all the station ids (now with '_' and 'INT' added)
with con:
    cur.execute('CREATE TABLE available_bikes (execution_time INT,' + ', '.join(station_ids) + ');')
    
# The syntax: + ', '.join(station_ids) has a space after the original comma because the station ids before the join look like
# '_72 INT', '_79 INT', etc. so we need a space after the comma so the code joins the station ids correctly. 

# The final addition; ');' closes the syntax so the code runs properly, SQL requires ';' to know the code has ended

# %%
#see created database:
pd.read_sql_query('SELECT * FROM available_bikes', con)
# Out:
# Empty DataFrame
# Columns: [execution_time, _72, _79, _82, _83, _116, _119, _120, _127, _128, _137, _143, _144, _146, _147, _150, _151, _152, _153, _157, _160, _161, _164, _167, _168, _173, _174, _195, _212, _216, _217, _218, _223, _224, _225, _228, _229, _232, _233, _236, _237, _238, _239, _241, _242, _243, _244, _245, _247, _248, _249, _250, _251, _252, _253, _254, _257, _258, _259, _260, _261, _262, _263, _264, _265, _266, _267, _268, _270, _274, _275, _276, _278, _279, _280, _281, _282, _284, _285, _289, _290, _291, _293, _294, _295, _296, _297, _298, _300, _301, _302, _303, _304, _305, _306, _307, _308, _309, _310, _311, ...]
# Index: []
#
# [0 rows x 513 columns]

# %% [markdown]
# <b>Comment:</b> Not sure exactly how this one is working - need clarification; specifically on: (execution_time INT, " +  ", ".join(station_ids) + ");")
# <b>Update:</b> Here, we are doing the following:
# 1. We’re creating a table and hard-coding the first column to be an integer.
# 2. Then we’re adding to that string ", ".join(station_ids), which is an easy way to concatenate strings in a list. For clarity,  x.join(y) uses x as a separator to connect all the elements in y together. For example, '-'.join([1, 2, 3]) becomes 1-2-3. In our case, ', '.join(['_72 INT', '_79 INT', ...]) becomes '_72 INT, _79 INT, ...'
# 3. The final line, after adding on the close paren, is 'CREATE TABLE available_bikes (execution_time INT, _72 INT, _79 INT, ...);'

# %% [markdown]
# Populate new database with our values for available bikes. First we need some packages to deal with dates and time:

# %%
import time # a package with datetime objects
from dateutil.parser import parse # a package for parsing a string into a Python datetime object
import collections
import datetime #required for code below

# %%
#take the string from our original database (nyc_bike) in the executionTime column and parse it into a Python datetime object:
exec_time = parse(nyc_bike.json()['executionTime'])
print exec_time
# Out:
# 2015-11-03 10:36:09

# %% [markdown]
# As you saw briefly in the lesson on time-series analysis, Python has a datetime object which stores datetime values. This object has attributes for year, month, day, hour, minute, second, microseconds, and timezone. In this case, we're creating a basic naive datetime object without specifying timezone.

# %%
# We create an entry for the execution time by inserting it into the database:
with con:    
    cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', [exec_time.strftime('%Y-%m-%dT%H:%M:%S')],)

# function strftime() formats the time.

# %%
print pd.read_sql_query('SELECT * FROM available_bikes', con)
# Out:
#         execution_time   _72   _79   _82   _83  _116  _119  _120  _127  _128  \
# 0  2015-11-03T10:36:09  None  None  None  None  None  None  None  None  None
#
#    ...  _3226 _3229 _3230 _3231 _3232 _3233 _3234 _3235 _3236 _3237
# 0  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 513 columns]

# %% [markdown]
# Then we iterate through the stations in the "stationBeanList":

# %%
id_bikes = collections.defaultdict(int) #defaultdict to store available bikes by station
id_bikes
# Out:
# defaultdict(int, {})

# %% [markdown]
# <b>Comment:</b> Do not understand how this default dict works and how I was supposed to know to create it using collections. Read the instructions several times over and see no reference to it. Will need to understand this part better.
#
# My current understanding is that this dictionary is set up with datatype 'int' for the key and then a dict for the values associated with that key. When we loop through the station list, each station (recorded as an INT) will be the key and the available bikes at that station will be the values associated with that key.
#
# <b>Update:</b> Suppose you have a dictionary 'my_dict' that you were using to accumulate other values. In a loop, you might write:
#
# ![](files/nycbike7.jpg)
#
# If, however, your dictionary is empty, the first time it attempts to modify one of the values, you’ll get a KeyError.
# When we write <i>x += y</i>, the computer actually runs <i>x = x + y</i> (most of the time, but this can be manually overridden). Thus, in the case of our empty dictionary, we have:
# my_dict[key] = my_dict[key] + value
# If the dictionary is empty, or is missing a particular key, it can’t resolve my_dict[key]. To correct this, you could initialize all the elements before you run the loop, but this requires you to know all the keys in advance, which you might not if you have a large set of data. The other option is to simply stop the loop when you notice my_dict is missing a key, initialize the key, and then resume the loop. This is exactly what defaultdict does—if it sees you trying to access a key that isn’t in the dictionary, it gives you a default value of the data type when you created it. The material introduces them in section 1.1.4, but doesn’t explain what they are and doesn’t use them again until section 3.1.4.

# %%
#loop through the stations in the station list and add them to a dictionary where the station ID is the key and the number
#of available bikes is the associated value
for station in nyc_bike.json()['stationBeanList']: #recall that we need to run the nyc_bike frame (original dataframe)
    id_bikes[station['id']] = station['availableBikes']
    
#iterate through the defaultdict to update the values in the database
with con:
    for k, v in id_bikes.iteritems(): #k = key (station ID), v = values (available bikes)
        cur.execute('UPDATE available_bikes SET _' + str(k) + '=' + str(v) + \
                    ' WHERE execution_time = ?;', [exec_time.strftime('%Y-%m-%dT%H:%M:%S')] )

# %% [markdown]
# <b>Comment:</b> Very confused with the above statements. I don't understand why certain characters have been placed into the code when there have been no mention as to why they are there. Will need to go through this step by step for to understand this sufficiently.
#
# <b>Update:</b> This is happening because you overlooked one of the parameters after correcting what I pointed out in my last email. Compare these two lines:
#
# ![](files/nycbike8.jpg)
#
# You accidentally left <i>+ ';'</i> at the end, after a comma, by itself, so python was attempting to evaluate it. Because you only have something on one side of the +, it’s being used as a unary operator (rather than its usual use as a binary operator), and so Python complains that the type str (i.e., your ;) can’t be used with the unary operator. <b>Also note that I added an extra space before WHERE, because otherwise str(v) + 'WHERE ...' would become, for example, '12WHERE ...'</b>

# %%
print pd.read_sql_query('SELECT * FROM available_bikes', con)
# Out:
#         execution_time  _72  _79  _82  _83  _116  _119  _120  _127  _128  \
# 0  2015-11-03T10:36:09    1   22   17   15     8     3     3    30     0
#
#    ...    _3226  _3229  _3230  _3231  _3232  _3233  _3234  _3235  _3236  _3237
# 0  ...        1      0      0     29      4     36     45     28      0      9
#
# [1 rows x 513 columns]

# %% [markdown]
# <b>Note:</b> If you have data in your available_bikes table and want to delete it, you can do that by running the query:
# <i>"DELETE FROM available_bikes".</i> <b>This will remove all rows in the table.</b>

# %%
with con:
    cur.execute('DELETE FROM available_bikes')
    
print pd.read_sql_query('SELECT * FROM available_bikes', con)
# Out:
# Empty DataFrame
# Columns: [execution_time, _72, _79, _82, _83, _116, _119, _120, _127, _128, _137, _143, _144, _146, _147, _150, _151, _152, _153, _157, _160, _161, _164, _167, _168, _173, _174, _195, _212, _216, _217, _218, _223, _224, _225, _228, _229, _232, _233, _236, _237, _238, _239, _241, _242, _243, _244, _245, _247, _248, _249, _250, _251, _252, _253, _254, _257, _258, _259, _260, _261, _262, _263, _264, _265, _266, _267, _268, _270, _274, _275, _276, _278, _279, _280, _281, _282, _284, _285, _289, _290, _291, _293, _294, _295, _296, _297, _298, _300, _301, _302, _303, _304, _305, _306, _307, _308, _309, _310, _311, ...]
# Index: []
#
# [0 rows x 513 columns]

# %% [markdown]
# <b>Update Above Code to Run for One Hour to Collect City Bike Data:</b>

# %% [markdown]
# The below code will run stand alone and return a complete database of available bikes every minute for each station.

# %%
con = lite.connect('citi_bike.db')
cur = con.cursor()

for i in range(60):
    nyc_bike = requests.get('http://www.citibikenyc.com/stations/json')
    exec_time = parse(nyc_bike.json()['executionTime'])

    with con:
        cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', [exec_time.strftime('%Y-%m-%dT%H:%M:%S')],)

    id_bikes = collections.defaultdict(int)
    for station in nyc_bike.json()['stationBeanList']:
        id_bikes[station['id']] = station['availableBikes']

    with con:
        for k, v in id_bikes.iteritems(): #k = key (station ID), v = values (available bikes)
            cur.execute('UPDATE available_bikes SET _' + str(k) + '=' + str(v) + \
                        ' WHERE execution_time = ?;', [exec_time.strftime('%Y-%m-%dT%H:%M:%S')] )

    time.sleep(60)

con.close() #close the database connection when done
